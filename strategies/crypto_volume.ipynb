# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
# If you're running the notebook from a subfolder, walk up until we find "data"
while not (PROJECT_ROOT / "data").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT))

# %%
import os
import time
import requests
import json
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

from data.providers.binance import BinanceProvider
from data.providers.coingecko import CoingeckoProvider

# %%
url = "https://api.coingecko.com/api/v3/coins/markets"
params = {
    "vs_currency": "usd",
    "order": "market_cap_desc",
    "per_page": 100,
    "page": 1,
    "sparkline": False,
}

response = requests.get(url, params=params)
coins = response.json()

print(f"{'#':<4} {'Symbol':<8} {'Name':<22} {'Price':>12} {'Market Cap':>18} {'24h Vol':>16} {'24h %':>8}")
print("-" * 92)

for i, c in enumerate(coins, 1):
    price = c['current_price'] or 0
    mcap = c['market_cap'] or 0
    vol = c['total_volume'] or 0
    change = c['price_change_percentage_24h'] or 0

    print(
        f"{i:<4} {c['symbol'].upper():<8} {c['name'][:20]:<22} "
        f"${price:>11,.2f} ${mcap:>16,.0f} "
        f"${vol:>14,.0f} "
        f"{change:>+7.2f}%"
    )
# Out:
# #    Symbol   Name                          Price         Market Cap          24h Vol    24h %
# --------------------------------------------------------------------------------------------
# 1    BTC      Bitcoin                $  76,509.00 $1,532,836,638,894 $32,876,128,687   +0.73%
# 2    ETH      Ethereum               $   2,108.93 $ 254,526,297,384 $15,927,488,683   +1.55%
# 3    USDT     Tether                 $       1.00 $ 189,482,452,007 $55,444,269,977   -0.00%
# 4    BNB      BNB                    $     655.15 $  88,308,826,895 $   763,940,642   +0.38%
# 5    XRP      XRP                    $       1.35 $  83,804,048,112 $ 1,835,936,364   +1.01%
# 6    USDC     USDC                   $       1.00 $  76,464,054,864 $10,412,710,656   -0.00%
# 7    SOL      Solana                 $      85.96 $  49,777,842,428 $ 3,303,596,864   +1.01%
# 8    TRX      TRON                   $       0.36 $  34,285,550,784 $   511,860,249   -0.23%
# 9    FIGR_HELOC Figure Heloc           $       1.03 $  18,627,042,084 $       106,080   -0.09%
# 10   DOGE     Dogecoin               $       0.10 $  15,925,769,851 $ 1,112,023,670   -0.85%
# 11   HYPE     Hyperliquid            $      57.74 $  13,882,971,139 $   899,992,094   +2.98%
# 12   USDS     USDS                   $       1.00 $  11,135,267,629 $    21,838,229   -0.00%
# 13   ZEC      Zcash                  $     635.30 $  10,602,087,007 $   844,854,889   +5.88%
# 14   LEO      LEO Token              $       9.96 $   9,170,041,824 $       294,236   +0.04%
# 15   ADA      Cardano                $       0.25 $   9,134,648,817 $   443,419,451   +0.20%
# 16   BCH      Bitcoin Cash           $     355.55 $   7,125,350,276 $   446,734,715   -4.90%
# 17   XMR      Monero                 $     386.17 $   7,124,191,601 $   109,081,546   +1.01%
# 18   LINK     Chainlink              $       9.59 $   6,988,491,880 $   333,026,991   +0.60%
# 19   WBT      WhiteBIT Coin          $      56.47 $   6,695,224,996 $    58,600,542   +1.01%
# 20   CC       Canton                 $       0.16 $   6,179,593,769 $     8,005,014   +1.84%
# 21   XLM      Stellar                $       0.15 $   4,936,425,093 $    98,955,411   +1.70%
# 22   TON      Toncoin                $       1.82 $   4,906,604,647 $   274,581,412   -3.86%
# 23   USD1     USD1                   $       1.00 $   4,782,016,358 $ 1,054,755,634   -0.04%
# 24   USDE     Ethena USDe            $       1.00 $   4,442,771,265 $    67,428,327   +0.01%
# 25   DAI      Dai                    $       1.00 $   4,346,174,526 $   144,711,005   +0.01%
# 26   SUI      Sui                    $       1.07 $   4,299,842,204 $   861,852,209   +0.81%
# 27   LTC      Litecoin               $      53.61 $   4,139,280,255 $   280,075,316   +0.65%
# 28   AVAX     Avalanche              $       9.44 $   4,083,779,645 $   251,250,572   +2.06%
# 29   HBAR     Hedera                 $       0.09 $   3,916,859,620 $    67,250,446   +1.32%
# 30   M        MemeCore               $       2.87 $   3,742,293,655 $     8,136,883   +3.54%
# 31   RAIN     Rain                   $       0.01 $   3,625,651,113 $    25,446,702   +3.13%
# 32   PYUSD    PayPal USD             $       1.00 $   3,614,395,576 $    61,621,327   -0.02%
# 33   SHIB     Shiba Inu              $       0.00 $   3,361,902,933 $    82,754,883   -0.84%
# 34   NEAR     NEAR Protocol          $       2.39 $   3,126,548,720 $ 1,061,531,500  +14.30%
# 35   CRO      Cronos                 $       0.07 $   3,117,835,542 $    10,358,559   +1.73%
# 36   USYC     Circle USYC            $       1.13 $   2,999,355,049 $         4,800   -0.01%
# 37   USDG     Global Dollar          $       1.00 $   2,748,113,146 $    44,088,388   -0.03%
# 38   TAO      Bittensor              $     283.21 $   2,717,093,018 $   243,716,102   +3.59%
# 39   XAUT     Tether Gold            $   4,502.34 $   2,669,167,602 $    95,170,663   +0.10%
# 40   BUIDL    BlackRock USD Instit   $       1.00 $   2,511,778,553 $             0   +0.00%
# 41   UNI      Uniswap                $       3.47 $   2,212,130,953 $   282,917,135   -1.40%
# 42   DOT      Polkadot               $       1.31 $   2,205,615,253 $   164,446,734   +1.62%
# 43   MNT      Mantle                 $       0.66 $   2,179,733,865 $    29,844,318   +2.89%
# 44   USDY     Ondo US Dollar Yield   $       1.14 $   2,149,836,206 $     3,096,601   +0.64%
# 45   PAXG     PAX Gold               $   4,510.26 $   2,120,967,245 $    76,970,024   +0.19%
# 46   ONDO     Ondo                   $       0.42 $   2,039,193,430 $   384,834,180   +7.35%
# 47   WLFI     World Liberty Financ   $       0.06 $   1,984,694,200 $    50,457,971   +2.59%
# 48   HTX      HTX DAO                $       0.00 $   1,810,060,125 $    48,317,474   -0.18%
# 49   USDF     Falcon USD             $       1.00 $   1,779,781,391 $       453,593   -0.01%
# 50   ASTER    Aster                  $       0.68 $   1,762,084,830 $    98,092,577   +0.83%
# 51   RLUSD    Ripple USD             $       1.00 $   1,759,607,355 $    92,503,282   +0.01%
# 52   OKB      OKB                    $      82.35 $   1,730,525,632 $    16,510,947   +0.59%
# 53   SKY      Sky                    $       0.07 $   1,634,242,401 $     7,911,306   +0.18%
# 54   PI       Pi Network             $       0.15 $   1,609,282,510 $    13,059,062   +0.32%
# 55   PEPE     Pepe                   $       0.00 $   1,535,322,177 $   221,878,689   -0.98%
# 56   USDD     USDD                   $       1.00 $   1,504,750,968 $     9,462,332   -0.06%
# 57   ICP      Internet Computer      $       2.60 $   1,440,980,072 $    79,611,077   +2.52%
# 58   ETC      Ethereum Classic       $       9.01 $   1,413,257,303 $    46,425,496   +1.64%
# 59   BGB      Bitget Token           $       1.97 $   1,382,569,611 $    13,969,285   -0.25%
# 60   MORPHO   Morpho                 $       2.10 $   1,329,180,325 $    15,580,248   +6.22%
# 61   AAVE     Aave                   $      87.39 $   1,328,304,313 $   166,618,766   +1.14%
# 62   BFUSD    BFUSD                  $       1.00 $   1,318,152,564 $     1,137,848   +0.00%
# 63   QNT      Quant                  $      77.81 $   1,131,142,849 $    17,188,182   +0.04%
# 64   USDTB    USDtb                  $       1.00 $   1,088,318,242 $     4,347,755   +0.02%
# 65   KCS      KuCoin                 $       8.05 $   1,084,066,841 $     2,996,419   +2.69%
# 66   ATOM     Cosmos Hub             $       2.12 $   1,082,845,261 $    40,739,344   +1.16%
# 67   EUTBL    Spiko EU T-Bills Mon   $       1.22 $   1,057,479,106 $             0   -0.04%
# 68   WLD      Worldcoin              $       0.30 $   1,036,056,921 $   226,406,277   +7.87%
# 69   ALGO     Algorand               $       0.12 $   1,031,442,241 $    30,783,957   +1.42%
# 70   U        United Stables         $       1.00 $   1,028,883,697 $     6,577,063   +0.12%
# 71   RENDER   Render                 $       1.94 $   1,008,957,114 $    84,610,407   +2.64%
# 72   USTB     Superstate Short Dur   $      11.09 $     986,339,421 $             0   +0.00%
# 73   POL      POL (ex-MATIC)         $       0.09 $     972,111,852 $    41,651,569   -0.53%
# 74   BCAP     Blockchain Capital     $     105.74 $     963,514,617 $             0   +0.00%
# 75   JTRSY    Janus Henderson Anem   $       1.10 $     939,189,290 $             0   +0.00%
# 76   ENA      Ethena                 $       0.10 $     930,879,088 $   102,523,575   +0.55%
# 77   KAS      Kaspa                  $       0.03 $     926,683,045 $    15,181,195   -0.62%
# 78   NEXO     NEXO                   $       0.88 $     879,046,508 $     8,525,479   +1.06%
# 79   VVV      Venice Token           $      18.48 $     857,487,468 $    63,808,067   +3.97%
# 80   APT      Aptos                  $       0.98 $     801,835,543 $    67,443,955   +2.36%
# 81   JST      JUST                   $       0.09 $     784,544,582 $    26,296,375   -1.10%
# 82   FIL      Filecoin               $       0.99 $     772,396,816 $    98,296,719   +0.03%
# 83   STABLE   ​​Stable               $       0.03 $     766,853,178 $    16,985,935   -2.32%
# 84   GT       Gate                   $       7.00 $     745,072,442 $     2,687,225   -0.29%
# 85   FLR      Flare                  $       0.01 $     724,901,310 $     2,275,222   +1.28%
# 86   JUP      Jupiter                $       0.21 $     697,845,250 $    24,923,891   +3.87%
# 87   ARB      Arbitrum               $       0.11 $     688,784,633 $    54,677,356   -0.02%
# 88   PUMP     Pump.fun               $       0.00 $     635,384,666 $    53,758,684   +2.52%
# 89   DEXE     DeXe                   $      13.55 $     633,704,410 $    10,501,609   -0.53%
# 90   XDC      XDC Network            $       0.03 $     633,211,899 $    19,490,496   -2.47%
# 91   BDX      Beldex                 $       0.08 $     608,666,678 $    10,707,606   -1.31%
# 92   HASH     Provenance Blockchai   $       0.01 $     607,768,929 $        18,964   -6.07%
# 93   VET      VeChain                $       0.01 $     588,226,464 $    15,703,764   +3.47%
# 94   GHO      GHO                    $       1.00 $     583,421,312 $     4,085,001   +0.03%
# 95   DASH     Dash                   $      45.84 $     583,270,635 $   145,553,725   +4.30%
# 96   PENGU    Pudgy Penguins         $       0.01 $     571,618,501 $   153,621,139   +0.01%
# 97   NIGHT    Midnight               $       0.03 $     560,859,955 $    11,930,285   +3.50%
# 98   USD0     Usual USD              $       1.00 $     554,387,446 $         3,836   +0.01%
# 99   OUSG     OUSG                   $     115.33 $     553,219,950 $             0   +0.00%
# 100  BONK     Bonk                   $       0.00 $     542,862,025 $    39,248,045   +1.72%

# %%
tickers = requests.get("https://api.binance.com/api/v3/ticker/24hr").json()
binance_map = {t['symbol']: t for t in tickers if t['symbol'].endswith('USDT')}
f'Number of coins: {len(binance_map)}'
# Out:
# 'Number of coins: 664'

# %%
matched = []
unmatched = []

for c in coins:
    symbol = c['symbol'].upper() + "USDT"
    if symbol in binance_map:
        matched.append({
            "coingecko_symbol": c['symbol'],
            "binance_symbol": symbol,
            "coingecko": c,
            "binance_ticker": binance_map[symbol],
        })
    else:
        unmatched.append(symbol)
    if len(matched) >= 100:
        break

f'Matched coins: {len(matched)}'
# Out:
# 'Matched coins: 62'

# %%
klines = requests.get("https://api.binance.com/api/v3/klines", params={
            "symbol": 'BTCUSDT',
            "interval": "1d",
            "limit": 30,
        }).json()

for kline in klines:
    time = kline[0]
    print(time)
    print(pd.to_datetime(time, unit = 'ms'))
    print(datetime.fromtimestamp(kline[0] / 1000).strftime("%Y-%m-%d"))
    break
# Out:
# 1776988800000
# 2026-04-24 00:00:00
# 2026-04-23

# %%
datetime.fromtimestamp(1776902400000 / 1000)
# Out:
# datetime.datetime(2026, 4, 22, 20, 0)

# %%
x = pd.Series([1, 2, 3, 4, 5])
x[:3].mean()
# Out:
# np.float64(2.0)

# %%
def relative_volume(volume, short = 5, long = 30):
    return volume[:short].mean() / volume[:long].mean()

# %% [markdown]
# >To transform time to datetime you must do `pd.to_datetime(time, unit='ms')`

# %%
for i, m in enumerate(matched):
    symbol = m['binance_symbol']
    klines = requests.get("https://api.binance.com/api/v3/klines", params={
        "symbol": symbol,
        "interval": "1d",
        "limit": 30,
    }).json()

    daily = []
    for k in klines:
        daily.append({
            "date": pd.to_datetime(k[0], unit = 'ms'),
            "open": float(k[1]),
            "high": float(k[2]),
            "low": float(k[3]),
            "close": float(k[4]),
            "volume": float(k[5]),           # base asset volume
            "volume_usdt": float(k[7]),       # quote volume in USDT
            "trades": int(k[8]),
        })

    m['daily_klines'] = daily

    # Volume change: compare day 1 vs day 5
    if len(daily) >= 2:
        vol_series = {day['date']: day['volume_usdt'] for day in daily}
        vol_series = pd.Series(vol_series)
        vol_series = vol_series.iloc[::-1]
        m['rvol'] = relative_volume(vol_series)
    else:
        print('Error calculating RVOL')
        m['rvol'] = 0
    
    if (i + 1) % 20 == 0:
        print(f"Fetched {i + 1}/{len(matched)}...")
# Out:
# Fetched 20/62...
# Fetched 40/62...
# Fetched 60/62...

# %%
STABLECOINS = {
    "USDT", "USDC", "BUSD", "DAI", "TUSD", "USDP", "USDD", "GUSD",
    "FRAX", "LUSD", "SUSD", "CRVUSD", "PYUSD", "FDUSD", "USDE",
    "EURC", "EURT", "GHO", "ALUSD", "MIM", "UST", "USTC",
    "USDB", "USD0", "USDS",
}

# filtered = [c for c in coins if c['symbol'].upper() not in STABLECOINS]
filtered = [m for m in matched if m['coingecko_symbol'].upper() not in STABLECOINS]

# %%
assets = []

print(f"\n{'#':<4} {'Symbol':<10} {'Mkt Cap':>14} {'Price':>12} {'5d Vol Chg':>11}")
print("-" * 55)

for i, m in enumerate(filtered, 1):
    c = m['coingecko']
    assets.append({
        "#": i,
        "Symbol": c['symbol'].upper(),
        "Mkt Cap": c['market_cap'],
        "Price": c['current_price'],
        "RVOL": m['rvol']
    })

    print(
        f"{i:<4} {c['symbol'].upper():<10} "
        f"${c['market_cap']:>12,.0f} "
        f"${c['current_price']:>10,.2f} "
        f"{m['rvol']:>+10.4f}%"
    )

df = pd.DataFrame(assets)
# Out:
# #    Symbol            Mkt Cap        Price  5d Vol Chg
# -------------------------------------------------------
# 1    BTC        $1,532,836,638,894 $ 76,509.00    +0.8535%
# 2    ETH        $254,526,297,384 $  2,108.93    +0.8381%
# 3    BNB        $88,308,826,895 $    655.15    +0.8440%
# 4    XRP        $83,804,048,112 $      1.35    +1.0158%
# 5    SOL        $49,777,842,428 $     85.96    +0.9837%
# 6    TRX        $34,285,550,784 $      0.36    +1.1120%
# 7    DOGE       $15,925,769,851 $      0.10    +0.5530%
# 8    ZEC        $10,602,087,007 $    635.30    +1.4022%
# 9    ADA        $9,134,648,817 $      0.25    +1.0298%
# 10   BCH        $7,125,350,276 $    355.55    +1.1542%
# 11   XMR        $7,124,191,601 $    386.17    +0.4050%
# 12   LINK       $6,988,491,880 $      9.59    +0.9477%
# 13   XLM        $4,936,425,093 $      0.15    +0.7523%
# 14   TON        $4,906,604,647 $      1.82    +0.5259%
# 15   USD1       $4,782,016,358 $      1.00    +1.9306%
# 16   SUI        $4,299,842,204 $      1.07    +1.3811%
# 17   LTC        $4,139,280,255 $     53.61    +0.9803%
# 18   AVAX       $4,083,779,645 $      9.44    +1.1448%
# 19   HBAR       $3,916,859,620 $      0.09    +1.0571%
# 20   SHIB       $3,361,902,933 $      0.00    +0.4981%
# 21   NEAR       $3,126,548,720 $      2.39    +2.9470%
# 22   TAO        $2,717,093,018 $    283.21    +0.9474%
# 23   XAUT       $2,669,167,602 $  4,502.34    +1.0442%
# 24   UNI        $2,212,130,953 $      3.47    +1.0253%
# 25   DOT        $2,205,615,253 $      1.31    +1.3007%
# 26   PAXG       $2,120,967,245 $  4,510.26    +0.7032%
# 27   ONDO       $2,039,193,430 $      0.42    +1.9095%
# 28   WLFI       $1,984,694,200 $      0.06    +0.4788%
# 29   ASTER      $1,762,084,830 $      0.68    +1.3978%
# 30   RLUSD      $1,759,607,355 $      1.00    +1.3996%
# 31   SKY        $1,634,242,401 $      0.07    +0.5959%
# 32   PEPE       $1,535,322,177 $      0.00    +0.5141%
# 33   ICP        $1,440,980,072 $      2.60    +0.7380%
# 34   ETC        $1,413,257,303 $      9.01    +0.8847%
# 35   MORPHO     $1,329,180,325 $      2.10    +1.0240%
# 36   AAVE       $1,328,304,313 $     87.39    +0.7259%
# 37   BFUSD      $1,318,152,564 $      1.00    +0.5033%
# 38   QNT        $1,131,142,849 $     77.81    +1.1110%
# 39   ATOM       $1,082,845,261 $      2.12    +0.9586%
# 40   WLD        $1,036,056,921 $      0.30    +2.0686%
# 41   ALGO       $1,031,442,241 $      0.12    +0.8044%
# 42   U          $1,028,883,697 $      1.00    +1.1637%
# 43   RENDER     $1,008,957,114 $      1.94    +1.6852%
# 44   POL        $ 972,111,852 $      0.09    +0.9392%
# 45   ENA        $ 930,879,088 $      0.10    +0.7892%
# 46   NEXO       $ 879,046,508 $      0.88    +0.9727%
# 47   APT        $ 801,835,543 $      0.98    +0.5561%
# 48   JST        $ 784,544,582 $      0.09    +1.1078%
# 49   FIL        $ 772,396,816 $      0.99    +0.6217%
# 50   JUP        $ 697,845,250 $      0.21    +0.5811%
# 51   ARB        $ 688,784,633 $      0.11    +0.7170%
# 52   PUMP       $ 635,384,666 $      0.00    +0.7895%
# 53   DEXE       $ 633,704,410 $     13.55    +0.6132%
# 54   VET        $ 588,226,464 $      0.01    +0.9852%
# 55   DASH       $ 583,270,635 $     45.84    +1.2851%
# 56   PENGU      $ 571,618,501 $      0.01    +0.7493%
# 57   NIGHT      $ 560,859,955 $      0.03    +0.8956%
# 58   BONK       $ 542,862,025 $      0.00    +0.5503%

# %%
binance = BinanceProvider()
pairs = binance.get_pairs()

# %%
coingecko = CoingeckoProvider()
coins = coingecko.get_top_coins()

# %%
stablecoins = coingecko.get_stablecoins()
# Out:
#   Loaded 210 stablecoin symbols (hardcoded + CoinGecko)

# %%
STABLECOINS_HARDCODED = {
    "USDT", "USDC", "BUSD", "DAI", "TUSD", "USDP", "USDD", "GUSD",
    "FRAX", "LUSD", "SUSD", "CRVUSD", "PYUSD", "FDUSD", "USDE",
    "EURC", "EURT", "GHO", "ALUSD", "MIM", "UST", "USTC",
    "USDB", "USD0", "USDS", "USDJ", "CUSD", "RSV", "PAX",
}
 
WRAPPED_TOKENS = {
    "WBTC", "WETH", "STETH", "CBETH", "RETH", "WBNB", "WMATIC",
    "WSOL", "WTRX", "HBTC", "RENBTC", "TBTC", "SBTC", "BETH",
    "METH", "MSOL", "BNSOL", "JITOSOL",
}

# %%
excluded = set(STABLECOINS_HARDCODED) | WRAPPED_TOKENS | stablecoins
candidates = []
for c in coins:
    sym = c["symbol"].upper()
    if sym in excluded:
        continue
    if sym in pairs:
        candidates.append({
            "symbol": sym,
            "coin_id": c["id"],
            "name": c["name"],
            "rank": c.get("market_cap_rank", 999),
            "binance_symbol": pairs[sym],
        })
    if len(candidates) >= 100:
        break

# %%
print(f"  Matched {len(candidates)} coins (filtered stables/wrapped, Binance-listed)")
for i, c in enumerate(candidates[:10], 1):
    print(f"    {i:>3}. {c['symbol']:<8} {c['name']}")
if len(candidates) > 10:
    print(f"    ... and {len(candidates) - 10} more")
# Out:
#   Matched 100 coins (filtered stables/wrapped, Binance-listed)
#       1. BTC      Bitcoin
#       2. ETH      Ethereum
#       3. BNB      BNB
#       4. XRP      XRP
#       5. SOL      Solana
#       6. TRX      TRON
#       7. DOGE     Dogecoin
#       8. ZEC      Zcash
#       9. ADA      Cardano
#      10. BCH      Bitcoin Cash
#     ... and 90 more

# %%
BINANCE_DAYS = 730
DAYS = 365
CACHE_DIR = "coin_cache"
OUTPUT_DIR = "backtest_data"

# %%
os.makedirs(CACHE_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
def merge_data(binance_data, coingecko_data):
    """Merge Binance volume with CoinGecko market cap by date"""
    cg_map = {}
    if coingecko_data:
        for row in coingecko_data:
            cg_map[row["date"]] = row
 
    merged = []
    for b in binance_data:
        date = b["date"]
        cg = cg_map.get(date, {})
        merged.append({
            "date": date,
            "open": b["open"],
            "high": b["high"],
            "low": b["low"],
            "close": b["close"],
            "volume_base": b["volume_base"],
            "volume_usdt": b["volume_usdt"],
            "trades": b["trades"],
            "market_cap": cg.get("cg_market_cap"),
            "cg_volume": cg.get("cg_volume"),
        })
    return merged

# %%
print(f"Fetching historical data ({BINANCE_DAYS}d volume + {DAYS}d market cap)...")
results = []
for i, coin in enumerate(candidates):
    sym = coin["symbol"]
    coin_id = coin["coin_id"]
    cache_file = os.path.join(CACHE_DIR, f"{sym}_{coin_id}.json")

    # Check cache
    if os.path.exists(cache_file):
        with open(cache_file) as f:
            cached = json.load(f)
        results.append(cached)
        print(f"  [{i+1:>3}/{len(candidates)}] {sym:<8} (cached)")
        continue

    print(f"  [{i+1:>3}/{len(candidates)}] {sym:<8} fetching...", end=" ", flush=True)

    # Binance klines
    binance_data = binance.get_klines(coin["binance_symbol"], days=BINANCE_DAYS)
    print(f"Binance: {len(binance_data)}d", end=" ", flush=True)

    # CoinGecko market chart
    time.sleep(7)
    cg_data = coingecko.get_coin_data(coin_id, days=DAYS)
    cg_len = len(cg_data) if cg_data else 0
    print(f"| CoinGecko: {cg_len}d", end=" ", flush=True)

    # Merge
    merged = merge_data(binance_data, cg_data)

    result = {
        "symbol": sym,
        "coin_id": coin_id,
        "name": coin["name"],
        "rank": coin["rank"],
        "merged": merged,
    }

    # Cache
    with open(cache_file, "w") as f:
        json.dump(result, f)

    results.append(result)
    print("✓")
# Out:
# Fetching historical data (730d volume + 365d market cap)...
#   [  1/100] BTC      (cached)
#   [  2/100] ETH      (cached)
#   [  3/100] BNB      (cached)
#   [  4/100] XRP      (cached)
#   [  5/100] SOL      (cached)
#   [  6/100] TRX      (cached)
#   [  7/100] DOGE     (cached)
#   [  8/100] ZEC      (cached)
#   [  9/100] ADA      (cached)
#   [ 10/100] BCH      (cached)
#   [ 11/100] LINK     (cached)
#   [ 12/100] XLM      (cached)
#   [ 13/100] TON      (cached)
#   [ 14/100] SUI      (cached)
#   [ 15/100] LTC      (cached)
#   [ 16/100] AVAX     (cached)
#   [ 17/100] HBAR     (cached)
#   [ 18/100] SHIB     (cached)
#   [ 19/100] NEAR     (cached)
#   [ 20/100] TAO      (cached)
#   [ 21/100] XAUT     (cached)
#   [ 22/100] UNI      (cached)
#   [ 23/100] DOT      (cached)
#   [ 24/100] PAXG     (cached)
#   [ 25/100] ONDO     (cached)
#   [ 26/100] WLFI     (cached)
#   [ 27/100] ASTER    (cached)
#   [ 28/100] SKY      (cached)
#   [ 29/100] PEPE     (cached)
#   [ 30/100] ICP      (cached)
#   [ 31/100] ETC      (cached)
#   [ 32/100] MORPHO   (cached)
#   [ 33/100] AAVE     (cached)
#   [ 34/100] QNT      (cached)
#   [ 35/100] ATOM     (cached)
#   [ 36/100] WLD      (cached)
#   [ 37/100] ALGO     (cached)
#   [ 38/100] RENDER   (cached)
#   [ 39/100] POL      (cached)
#   [ 40/100] ENA      (cached)
#   [ 41/100] NEXO     (cached)
#   [ 42/100] APT      (cached)
#   [ 43/100] JST      (cached)
#   [ 44/100] FIL      (cached)
#   [ 45/100] JUP      (cached)
#   [ 46/100] ARB      (cached)
#   [ 47/100] PUMP     (cached)
#   [ 48/100] DEXE     (cached)
#   [ 49/100] VET      (cached)
#   [ 50/100] DASH     (cached)
#   [ 51/100] PENGU    (cached)
#   [ 52/100] NIGHT    (cached)
#   [ 53/100] BONK     (cached)
#   [ 54/100] INJ      (cached)
#   [ 55/100] VIRTUAL  (cached)
#   [ 56/100] TRUMP    (cached)
#   [ 57/100] FET      (cached)
#   [ 58/100] CAKE     (cached)
#   [ 59/100] STX      (cached)
#   [ 60/100] KITE     (cached)
#   [ 61/100] LUNC     (cached)
#   [ 62/100] 币安人生     (cached)
#   [ 63/100] SEI      (cached)
#   [ 64/100] TIA      (cached)
#   [ 65/100] CHZ      (cached)
#   [ 66/100] SUN      (cached)
#   [ 67/100] XTZ      (cached)
#   [ 68/100] 2Z       (cached)
#   [ 69/100] CRV      (cached)
#   [ 70/100] ZRO      (cached)
#   [ 71/100] ETHFI    (cached)
#   [ 72/100] PYTH     (cached)
#   [ 73/100] PENDLE   (cached)
#   [ 74/100] GNO      (cached)
#   [ 75/100] KAIA     (cached)
#   [ 76/100] LDO      (cached)
#   [ 77/100] CFX      (cached)
#   [ 78/100] GRT      (cached)
#   [ 79/100] DCR      (cached)
#   [ 80/100] FLOKI    (cached)
#   [ 81/100] OP       (cached)
#   [ 82/100] JASMY    (cached)
#   [ 83/100] STRK     (cached)
#   [ 84/100] IOTA     (cached)
#   [ 85/100] ENS      (cached)
#   [ 86/100] JTO      (cached)
#   [ 87/100] SYRUP    (cached)
#   [ 88/100] GENIUS   (cached)
#   [ 89/100] XPL      (cached)
#   [ 90/100] RAY      (cached)
#   [ 91/100] AXS      (cached)
#   [ 92/100] NEO      (cached)
#   [ 93/100] FF       (cached)
#   [ 94/100] THETA    (cached)
#   [ 95/100] COMP     (cached)
#   [ 96/100] WIF      (cached)
#   [ 97/100] SAND     (cached)
#   [ 98/100] TWT      (cached)
#   [ 99/100] S        (cached)
#   [100/100] MANA     (cached)

# %%
df = pd.read_csv("backtest_data/_master.csv", parse_dates=["date"])
bt = df[~df['market_cap'].isna()]
volume_df = pd.pivot_table(bt, values='volume_usdt', index='date', columns='symbol')
price_df = pd.pivot_table(bt, values='close', index='date', columns='symbol')
volume_df
# Out:
# symbol                2Z          AAVE           ADA          ALGO  \
# date
# 2025-05-24           NaN  7.621414e+07  5.540998e+07  4.399690e+06
# 2025-05-25           NaN  5.898738e+07  5.987951e+07  4.990341e+06
# 2025-05-26           NaN  5.538730e+07  6.080568e+07  5.768696e+06
# 2025-05-27           NaN  4.694125e+07  6.959419e+07  5.076279e+06
# 2025-05-28           NaN  3.521434e+07  5.648667e+07  4.925346e+06
# ...                  ...           ...           ...           ...
# 2026-05-19  4.947722e+05  8.051010e+06  1.948018e+07  4.618629e+06
# 2026-05-20  2.861189e+06  1.047395e+07  2.075863e+07  4.255397e+06
# 2026-05-21  7.001588e+06  1.129311e+07  2.677901e+07  2.764025e+06
# 2026-05-22  2.828208e+06  1.522175e+07  3.344317e+07  3.653071e+06
# 2026-05-23  9.276497e+05  5.176671e+06  1.579131e+07  8.738814e+05
#
# symbol               APT           ARB         ASTER          ATOM  \
# date
# 2025-05-24  1.332654e+07  1.125895e+07           NaN  6.216916e+06
# 2025-05-25  1.854867e+07  1.221195e+07           NaN  7.473315e+06
# 2025-05-26  1.819124e+07  2.179767e+07           NaN  6.723292e+06
# 2025-05-27  1.871807e+07  2.490309e+07           NaN  9.582279e+06
# 2025-05-28  2.436809e+07  2.710587e+07           NaN  8.309320e+06
# ...                  ...           ...           ...           ...
# 2026-05-19  3.324677e+06  2.175190e+06  4.932854e+06  3.055554e+06
# 2026-05-20  3.162404e+06  4.482348e+06  1.943569e+07  1.645985e+06
# 2026-05-21  5.946338e+06  6.123499e+06  3.724575e+07  3.300935e+06
# 2026-05-22  8.415693e+06  5.830481e+06  1.857725e+07  5.116940e+06
# 2026-05-23  2.546879e+06  2.664265e+06  7.035617e+06  1.742886e+06
#
# symbol              AVAX           AXS  ...           WLD          WLFI  \
# date                                    ...
# 2025-05-24  4.393987e+07  2.342084e+06  ...  9.368285e+07           NaN
# 2025-05-25  3.529042e+07  2.783534e+06  ...  5.451591e+07           NaN
# 2025-05-26  3.948337e+07  2.113150e+06  ...  7.077172e+07           NaN
# 2025-05-27  5.464893e+07  2.698747e+06  ...  7.932585e+07           NaN
# 2025-05-28  4.297977e+07  2.244375e+06  ...  6.257854e+07           NaN
# ...                  ...           ...  ...           ...           ...
# 2026-05-19  9.536213e+06  2.495249e+06  ...  8.459650e+06  3.410884e+06
# 2026-05-20  1.286308e+07  1.471063e+06  ...  1.367057e+07  3.075858e+06
# 2026-05-21  2.771812e+07  1.130469e+06  ...  2.212035e+07  4.155041e+06
# 2026-05-22  2.172276e+07  1.283416e+06  ...  5.035939e+07  6.968636e+06
# 2026-05-23  1.258552e+07  6.638361e+05  ...  9.630737e+06  3.657655e+06
#
# symbol              XAUT           XLM           XPL           XRP  \
# date
# 2025-05-24           NaN  8.661560e+06           NaN  1.185756e+08
# 2025-05-25           NaN  1.142690e+07           NaN  1.876262e+08
# 2025-05-26           NaN  9.255882e+06           NaN  1.752319e+08
# 2025-05-27           NaN  1.136681e+07           NaN  2.177019e+08
# 2025-05-28           NaN  1.330121e+07           NaN  2.272597e+08
# ...                  ...           ...           ...           ...
# 2026-05-19  2.133452e+07  1.103246e+07  2.904085e+06  1.352435e+08
# 2026-05-20  1.629845e+07  5.681002e+06  4.659671e+06  9.420712e+07
# 2026-05-21  1.185341e+07  5.595088e+06  6.551480e+06  1.069471e+08
# 2026-05-22  9.733901e+06  6.436419e+06  6.445452e+06  1.245409e+08
# 2026-05-23  1.067504e+06  2.556983e+06  3.131387e+06  6.639946e+07
#
# symbol               XTZ           ZEC           ZRO          币安人生
# date
# 2025-05-24  9.386291e+05  1.772452e+06  6.245692e+06           NaN
# 2025-05-25  9.886939e+05  7.624133e+06  4.892352e+06           NaN
# 2025-05-26  9.368071e+05  7.524661e+06  7.171436e+06           NaN
# 2025-05-27  1.482671e+06  6.366341e+06  5.506790e+06           NaN
# 2025-05-28  2.047013e+06  4.691489e+06  5.346274e+06           NaN
# ...                  ...           ...           ...           ...
# 2026-05-19  3.752369e+05  1.184165e+08  2.271900e+06  1.927269e+07
# 2026-05-20  2.355751e+05  2.280593e+08  1.840368e+06  3.573999e+07
# 2026-05-21  4.678876e+05  1.316197e+08  1.914331e+06  7.255174e+06
# 2026-05-22  3.374891e+05  1.303320e+08  2.500364e+06  7.001317e+06
# 2026-05-23  2.006418e+05  6.303892e+07  1.190905e+06  3.272285e+06
#
# [365 rows x 100 columns]

# %%
K = 5
FEE_RATE = 0.001
SHORT_SMA = 5
LONG_SMA = 30

short_sma= volume_df.rolling(SHORT_SMA).mean()
long_sma = volume_df.rolling(LONG_SMA).mean()
rvol = short_sma / long_sma

# %%
signal = {}

for i, row in rvol.iterrows():

    clean = row.dropna()
    
    if clean.notna().sum() >= 10:
        top = clean.nlargest(5)
        bot = clean.nsmallest(5)

        signal[i] = {
            'top': list(top.index),
            'bot': list(bot.index)
        }

# %%
rts = price_df.pct_change().shift(-1)
rts
# Out:
# symbol            2Z      AAVE       ADA      ALGO       APT       ARB  \
# date
# 2025-05-24       NaN  0.028375  0.017544  0.003623 -0.008845  0.004335
# 2025-05-25       NaN -0.006536  0.000790 -0.012184  0.005316 -0.004062
# 2025-05-26       NaN  0.015139 -0.002762  0.014162  0.013975  0.024471
# 2025-05-27       NaN -0.024229 -0.014111 -0.020270  0.004656  0.019408
# 2025-05-28       NaN -0.056568 -0.034109 -0.036322 -0.043382 -0.032463
# ...              ...       ...       ...       ...       ...       ...
# 2026-05-19  0.167322  0.007206  0.004029  0.043478  0.021505 -0.029956
# 2026-05-20  0.086831  0.001136  0.006019 -0.022109  0.025263  0.026340
# 2026-05-21 -0.056599 -0.022573 -0.033107 -0.028696 -0.034908 -0.037168
# 2026-05-22  0.023848 -0.030985 -0.013614 -0.013429 -0.027660 -0.034926
# 2026-05-23       NaN       NaN       NaN       NaN       NaN       NaN
#
# symbol         ASTER      ATOM      AVAX       AXS  ...       WLD      WLFI  \
# date                                                ...
# 2025-05-24       NaN  0.015907  0.021341  0.000352  ...  0.011388       NaN
# 2025-05-25       NaN -0.002923 -0.016205 -0.011248  ... -0.038705       NaN
# 2025-05-26       NaN -0.004606  0.013437  0.021330  ...  0.027086       NaN
# 2025-05-27       NaN  0.019142  0.009410  0.002436  ... -0.032787       NaN
# 2025-05-28       NaN -0.047678 -0.057203 -0.023264  ... -0.034635       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2026-05-19  0.055385 -0.024008  0.020637  0.030848  ...  0.039413  0.045000
# 2026-05-20  0.010204  0.030120  0.016670  0.000000  ...  0.083501 -0.004785
# 2026-05-21 -0.033189  0.008772 -0.031630 -0.044888  ...  0.007446 -0.035256
# 2026-05-22  0.000000 -0.020290 -0.026546 -0.018277  ... -0.015152  0.009967
# 2026-05-23       NaN       NaN       NaN       NaN  ...       NaN       NaN
#
# symbol          XAUT       XLM       XPL       XRP       XTZ       ZEC  \
# date
# 2025-05-24       NaN  0.006294       NaN  0.004892  0.005685  0.102849
# 2025-05-25       NaN -0.006949       NaN -0.013409 -0.013243 -0.004580
# 2025-05-26       NaN  0.004549       NaN  0.002813  0.017185 -0.044911
# 2025-05-27       NaN -0.006270       NaN -0.018387  0.036846  0.026787
# 2025-05-28       NaN -0.022783       NaN -0.013191 -0.043451 -0.001502
# ...              ...       ...       ...       ...       ...       ...
# 2026-05-19  0.010527  0.002089  0.068543  0.004113  0.021863  0.173456
# 2026-05-20 -0.002509  0.019458  0.028637  0.004901  0.025791 -0.013496
# 2026-05-21 -0.006895 -0.021813 -0.084633 -0.028677 -0.043429 -0.122778
# 2026-05-22  0.000367 -0.016028 -0.030414 -0.011990 -0.005376  0.011907
# 2026-05-23       NaN       NaN       NaN       NaN       NaN       NaN
#
# symbol           ZRO      币安人生
# date
# 2025-05-24  0.015736       NaN
# 2025-05-25 -0.002951       NaN
# 2025-05-26  0.005179       NaN
# 2025-05-27 -0.004049       NaN
# 2025-05-28 -0.041390       NaN
# ...              ...       ...
# 2026-05-19  0.026395  0.055182
# 2026-05-20  0.005878  0.003865
# 2026-05-21 -0.059898 -0.040091
# 2026-05-22 -0.025641  0.000236
# 2026-05-23       NaN       NaN
#
# [365 rows x 100 columns]

# %%
fee_rate = 0.001
strat = {}
strat_net = {}
strat_net_long = {}

prev_weights = pd.Series(0, index=rts.columns)
prev_weights_long = pd.Series(0, index=rts.columns)

for i, row in rts.iterrows():
    selection = signal.get(i, None)
    if selection is not None:
        long = row[selection['top']].mean()
        short = -row[selection['bot']].mean()

        weights = pd.Series(0.0, index=row.index)
        weights_long = weights.copy()

        weights_long[selection['top']] =  1 / len(selection['top'])
        weights[selection['top']] =  1 / len(selection['top'])
        weights[selection['bot']] = -1 / len(selection['bot'])
        
        gross_return = (weights * row).sum()
        turnover = (weights - prev_weights).abs().sum()
        transaction_cost = turnover * FEE_RATE
        net_return = gross_return - transaction_cost

        gross_return_long = (weights_long * row).sum()
        turnover_long = (weights_long - prev_weights_long).abs().sum()
        transaction_cost_long = turnover_long * FEE_RATE
        net_return_long = gross_return_long - transaction_cost_long
        
        portfolio = long + short
        
        strat[i] = portfolio
        strat_net[i] = net_return
        strat_net_long[i] = net_return_long

        prev_weights = weights
        prev_weights_long = weights_long
        
strat = pd.Series(strat)
strat_net = pd.Series(strat_net)
strat_net_long = pd.Series(strat_net_long)

# %%
hold_strat = {}
hold_strat_net = {}

active_tranches = {}
prev_weights = pd.Series(0.0, index=rts.columns)

for i, row in rts.iterrows():

    selection = signal.get(i, None)
    if selection is not None:
        w = pd.Series(0.0, index=row.index)
        w[selection['top']] =  1 / len(selection['top'])
        w[selection['bot']] = -1 / len(selection['bot'])
        active_tranches[i] = {'weights': w, 'days_left': K}

    if not active_tranches:
        continue

    combined_weights = pd.Series(0.0, index=row.index)
    for tranche in active_tranches.values():
        combined_weights += tranche['weights'] / K


    gross_return = (combined_weights * row).sum()
    turnover = (combined_weights - prev_weights).abs().sum()
    net_return = gross_return - turnover * fee_rate

    hold_strat[i] = gross_return
    hold_strat_net[i] = net_return

    prev_weights = combined_weights.copy()

    if len(active_tranches) > 5:
        print("Too many tranches")
    elif len(active_tranches) < 5:
        print(f'Observation with {len(active_tranches)} tranches')

    expired = [d for d, t in active_tranches.items() if t['days_left'] == 1]
    for d in expired:
        del active_tranches[d]
    for t in active_tranches.values():
        t['days_left'] -= 1

hold_strat     = pd.Series(hold_strat)
hold_strat_net = pd.Series(hold_strat_net)
# Out:
# Observation with 1 tranches
# Observation with 2 tranches
# Observation with 3 tranches
# Observation with 4 tranches

# %%
equity = (strat + 1).cumprod()
equity_net = (strat_net + 1).cumprod()
equity_net_long = (strat_net_long + 1).cumprod()
equity_hold = (hold_strat + 1).cumprod()
equity_hold_net = (hold_strat_net + 1).cumprod()

btc = rts['BTC'].reindex(equity.index)
btc = (1 + btc).cumprod()
eth = rts['ETH'].reindex(equity.index)
eth = (1 + eth).cumprod()
bnb = rts['BNB'].reindex(equity.index)
bnb = (1 + bnb).cumprod()

plt.figure(figsize=(10, 5))

plt.plot(equity, label='Startegy')
plt.plot(equity_net, label='Startegy Net')

plt.plot(equity_net_long, label='Startegy Long Only')

plt.plot(equity_hold, label='Startegy Hold')
plt.plot(equity_hold_net, label='Startegy Hold Net')

plt.plot(btc, label='Bitcoin')
plt.plot(eth, label='Ethereum')
plt.plot(bnb, label='BNB')

plt.legend()
plt.grid()
plt.show()

# %%
futures_spot_list = binance.get_futures_w_spot()

# %%
futures = []

for symbol in futures_spot_list['futures_symbol']:
    resp = binance.get_klines(symbol, source='FUTURES', days=365)
    futures.extend(resp)

df_futures = pd.DataFrame(futures)
df_futures
# Out:
#           symbol        date     open     high      low    close  volume_base  \
# 0         0GUSDT  2025-09-17  1.10000  3.20000  1.10000  2.78150  115465580.0
# 1         0GUSDT  2025-09-18  2.77970  3.63990  2.20710  2.80670  215889475.0
# 2         0GUSDT  2025-09-19  2.80690  3.01000  2.52260  2.76940   78480860.0
# 3         0GUSDT  2025-09-20  2.76930  2.85300  2.61000  2.63990   27845564.0
# 4         0GUSDT  2025-09-21  2.64030  3.65000  2.25380  3.15300   92862895.0
# ...          ...         ...      ...      ...      ...      ...          ...
# 122761  币安人生USDT  2026-05-19  0.46114  0.47792  0.40935  0.41682  152542454.0
# 122762  币安人生USDT  2026-05-20  0.41684  0.45660  0.41108  0.43944   83346155.0
# 122763  币安人生USDT  2026-05-21  0.43944  0.46633  0.43200  0.44106   57683520.0
# 122764  币安人生USDT  2026-05-22  0.44110  0.45037  0.42000  0.42371   44373117.0
# 122765  币安人生USDT  2026-05-23  0.42378  0.45024  0.41404  0.44672   51108464.0
#
#          volume_usdt   trades
# 0       2.480649e+08  2580380
# 1       5.704244e+08  5375891
# 2       2.181491e+08  5557746
# 3       7.623917e+07  1338848
# 4       2.732149e+08  2550390
# ...              ...      ...
# 122761  6.821186e+07   701530
# 122762  3.649846e+07   463475
# 122763  2.576472e+07   296417
# 122764  1.929084e+07   257097
# 122765  2.204933e+07   268625
#
# [122766 rows x 9 columns]

# %%
spot = []

for symbol in futures_spot_list['spot_symbol']:
    resp = binance.get_klines(symbol, source='SPOT', days=365)
    spot.extend(resp)

df_spot = pd.DataFrame(spot)
df_spot
# Out:
#           symbol        date    open    high     low   close  volume_base  \
# 0         0GUSDT  2025-09-22  1.0000  7.2600  1.0000  4.8390  69411652.78
# 1         0GUSDT  2025-09-23  4.8380  7.1800  4.5660  5.8150  52749822.84
# 2         0GUSDT  2025-09-24  5.8200  5.8950  4.8380  5.0050  19526670.81
# 3         0GUSDT  2025-09-25  5.0060  5.0140  3.6490  3.9170  13281842.95
# 4         0GUSDT  2025-09-26  3.9170  4.4550  3.3410  3.6790  14793109.26
# ...          ...         ...     ...     ...     ...     ...          ...
# 121981  币安人生USDT  2026-05-19  0.4605  0.4791  0.4094  0.4168  43127846.80
# 121982  币安人生USDT  2026-05-20  0.4168  0.4565  0.4108  0.4398  84146195.40
# 121983  币安人生USDT  2026-05-21  0.4399  0.4657  0.4324  0.4415  16206583.40
# 121984  币安人生USDT  2026-05-22  0.4415  0.4505  0.4207  0.4238  16116850.00
# 121985  币安人生USDT  2026-05-23  0.4239  0.4500  0.4143  0.4468  15258746.50
#
#          volume_usdt   trades
# 0       3.436885e+08  1204307
# 1       3.049379e+08  1340566
# 2       1.022588e+08   512620
# 3       5.364342e+07   370729
# 4       5.669995e+07   317501
# ...              ...      ...
# 121981  1.927269e+07   177439
# 121982  3.573999e+07   108472
# 121983  7.255174e+06    66824
# 121984  7.001317e+06    66385
# 121985  6.595624e+06    79175
#
# [121986 rows x 9 columns]

# %%
futures_spot_list
# Out:
#      base_asset     spot_symbol  futures_symbol
# 0            0G          0GUSDT          0GUSDT
# 1       1000CAT     1000CATUSDT     1000CATUSDT
# 2    1000CHEEMS  1000CHEEMSUSDT  1000CHEEMSUSDT
# 3      1000SATS    1000SATSUSDT    1000SATSUSDT
# 4         1INCH       1INCHUSDT       1INCHUSDT
# ..          ...             ...             ...
# 360         ZKC         ZKCUSDT         ZKCUSDT
# 361         ZKP         ZKPUSDT         ZKPUSDT
# 362         ZRO         ZROUSDT         ZROUSDT
# 363         ZRX         ZRXUSDT         ZRXUSDT
# 364        币安人生        币安人生USDT        币安人生USDT
#
# [365 rows x 3 columns]

# %%
excluded = set(STABLECOINS_HARDCODED) | WRAPPED_TOKENS | stablecoins
future_candidates = []
for c in coins:
    sym = c["symbol"].upper()
    if sym in excluded:
        continue
    if sym in futures_spot_list['base_asset'].values:
        _, spot, future = futures_spot_list[futures_spot_list['base_asset'] == sym].values[0]
        future_candidates.append({
            "symbol": sym,
            "coin_id": c["id"],
            "name": c["name"],
            "rank": c.get("market_cap_rank", 999),
            "binance_spot": spot,
            "binance_future": future
        })
    if len(future_candidates) >= 100:
        break

# %%
spot_filter = [c['binance_spot'] for c in future_candidates]
futuers_filter = [c['binance_future'] for c in future_candidates]
df_spot_filtered = df_spot[df_spot['symbol'].isin(spot_filter)]
df_futures_filtered = df_futures[df_futures['symbol'].isin(futuers_filter)]

# %%
spot_volume = pd.pivot_table(df_spot_filtered, values='volume_usdt', index='date', columns='symbol')
spot_px = pd.pivot_table(df_spot_filtered, values='close', index='date', columns='symbol')
future_px = pd.pivot_table(df_futures_filtered, values='close', index='date', columns='symbol')

# %%
short_sma= spot_volume.rolling(SHORT_SMA).mean()
long_sma = spot_volume.rolling(LONG_SMA).mean()
rvol = short_sma / long_sma

signal_ext = {}

for i, row in rvol.iterrows():

    clean = row.dropna()
    
    if clean.notna().sum() >= 10:
        top = clean.nlargest(5)
        bot = clean.nsmallest(5)

        signal_ext[i] = {
            'top': list(top.index),
            'bot': list(bot.index)
        }

# %%
future_rts = future_px.pct_change().shift(-1)
spot_rts = spot_px.pct_change().shift(-1)
future_rts
# Out:
# symbol        2ZUSDT  AAVEUSDC   ADAUSDC  ALGOUSDT   APTUSDT   ARBUSDC  \
# date
# 2025-05-24       NaN       NaN  0.017264  0.004080 -0.008813  0.004593
# 2025-05-25       NaN       NaN  0.000658 -0.013093  0.005263 -0.004064
# 2025-05-26       NaN       NaN -0.002498  0.014639  0.014250  0.024739
# 2025-05-27       NaN       NaN -0.014103 -0.019387  0.004528  0.018915
# 2025-05-28       NaN       NaN -0.034225 -0.036782 -0.043331 -0.032487
# ...              ...       ...       ...       ...       ...       ...
# 2026-05-19  0.166441  0.006642  0.004437  0.044405  0.022488 -0.030864
# 2026-05-20  0.089013  0.001365  0.005622 -0.022959  0.024098  0.026388
# 2026-05-21 -0.057358 -0.022722 -0.033147 -0.029591 -0.034834 -0.037234
# 2026-05-22  0.011662  0.025343  0.027675  0.043049  0.058554  0.022099
# 2026-05-23       NaN       NaN       NaN       NaN       NaN       NaN
#
# symbol      ASTERUSDT  ATOMUSDT  AVAXUSDC   AXSUSDT  ...  WLFIUSDC  XAUTUSDT  \
# date                                                 ...
# 2025-05-24        NaN  0.015492  0.021569  0.000704  ...       NaN       NaN
# 2025-05-25        NaN -0.002299 -0.016549 -0.011264  ...       NaN       NaN
# 2025-05-26        NaN -0.004608  0.013662  0.022428  ...       NaN       NaN
# 2025-05-27        NaN  0.018939  0.009969  0.001393  ...       NaN       NaN
# 2025-05-28        NaN -0.047708 -0.057911 -0.023992  ...       NaN       NaN
# ...               ...       ...       ...       ...  ...       ...       ...
# 2026-05-19   0.055282 -0.023553  0.020895  0.029135  ...  0.045075  0.010720
# 2026-05-20   0.011820  0.030151  0.017128  0.001665  ... -0.003195 -0.002523
# 2026-05-21  -0.034756  0.008780 -0.032197 -0.045719  ... -0.036859 -0.007186
# 2026-05-22   0.024204  0.029014  0.039724  0.048780  ...  0.046589  0.004099
# 2026-05-23        NaN       NaN       NaN       NaN  ...       NaN       NaN
#
# symbol       XLMUSDT   XPLUSDT   XRPUSDC   XTZUSDT   ZECUSDC    ZKUSDT  \
# date
# 2025-05-24  0.006299       NaN  0.004806  0.004878       NaN -0.002997
# 2025-05-25 -0.007129       NaN -0.013494 -0.011327       NaN -0.029905
# 2025-05-26  0.005079       NaN  0.002900  0.016367       NaN  0.023813
# 2025-05-27 -0.006307       NaN -0.018516  0.035427       NaN -0.017843
# 2025-05-28 -0.023146       NaN -0.013456 -0.041991       NaN -0.023358
# ...              ...       ...       ...       ...       ...       ...
# 2026-05-19  0.001812  0.069853  0.003971  0.020977  0.172852  0.033063
# 2026-05-20  0.020109  0.027491  0.005200  0.025829 -0.013330  0.018289
# 2026-05-21 -0.021622 -0.084727 -0.029071 -0.043491 -0.122227 -0.065427
# 2026-05-22  0.037507  0.048721  0.022512  0.045468  0.124663  0.056280
# 2026-05-23       NaN       NaN       NaN       NaN       NaN       NaN
#
# symbol       ZROUSDT  币安人生USDT
# date
# 2025-05-24  0.015635       NaN
# 2025-05-25 -0.003655       NaN
# 2025-05-26  0.005669       NaN
# 2025-05-27 -0.003979       NaN
# 2025-05-28 -0.041577       NaN
# ...              ...       ...
# 2026-05-19  0.025660  0.054268
# 2026-05-20  0.006917  0.003687
# 2026-05-21 -0.060436 -0.039337
# 2026-05-22  0.053745  0.054306
# 2026-05-23       NaN       NaN
#
# [365 rows x 100 columns]

# %%
def get_futures_symbols(symbols):
    return list(futures_spot_list[futures_spot_list['spot_symbol']
                                  .isin(symbols)]['futures_symbol']
                                  .values)

# %%
fee_rate = 0.0005
futures_strat = {}
futures_strat_net = {}

prev_weights = pd.Series(0, index=future_rts.columns)

for i, row in future_rts.iterrows():
    date = datetime.strptime(i, "%Y-%m-%d")
    selection = signal_ext.get(i, None)
    
    if selection is not None:
        
        top_symbols = get_futures_symbols(selection['top'])
        bot_symbols = get_futures_symbols(selection['bot'])
        long = row[top_symbols].mean()
        short = -row[bot_symbols].mean()

        weights = pd.Series(0.0, index=row.index)
        weights_long = weights.copy()

        weights[top_symbols] =  1 / len(top_symbols)
        weights[bot_symbols] = -1 / len(bot_symbols)
        
        gross_return = (weights * row).sum()
        turnover = (weights - prev_weights).abs().sum()
        transaction_cost = turnover * fee_rate
        net_return = gross_return - transaction_cost
        
        portfolio = long + short
        
        futures_strat[date] = portfolio
        futures_strat_net[date] = net_return

        prev_weights = weights
        
futures_strat = pd.Series(futures_strat)
futures_strat_net = pd.Series(futures_strat_net)

# %%
hold_futures_strat = {}
hold_futures_strat_net = {}

active_tranches = {}
prev_weights = pd.Series(0.0, index=future_rts.columns)

for i, row in future_rts.iterrows():
    date = datetime.strptime(i, "%Y-%m-%d")
    selection = signal_ext.get(i, None)
    
    if selection is not None:
        top_symbols = get_futures_symbols(selection['top'])
        bot_symbols = get_futures_symbols(selection['bot'])
        
        w = pd.Series(0.0, index=row.index)
        w[top_symbols] =  1 / len(top_symbols)
        w[bot_symbols] = -1 / len(bot_symbols)
        active_tranches[i] = {'weights': w, 'days_left': K}

    if not active_tranches:
        continue

    combined_weights = pd.Series(0.0, index=row.index)
    for tranche in active_tranches.values():
        combined_weights += tranche['weights'] / K


    gross_return = (combined_weights * row).sum()
    turnover = (combined_weights - prev_weights).abs().sum()
    net_return = gross_return - turnover * fee_rate

    hold_futures_strat[date] = gross_return
    hold_futures_strat_net[date] = net_return

    prev_weights = combined_weights.copy()

    if len(active_tranches) > 5:
        print("Too many tranches")
    elif len(active_tranches) < 5:
        print(f'Observation with {len(active_tranches)} tranches')

    expired = [d for d, t in active_tranches.items() if t['days_left'] == 1]
    for d in expired:
        del active_tranches[d]
    for t in active_tranches.values():
        t['days_left'] -= 1

hold_futures_strat     = pd.Series(hold_futures_strat)
hold_futures_strat_net = pd.Series(hold_futures_strat_net)
# Out:
# Observation with 1 tranches
# Observation with 2 tranches
# Observation with 3 tranches
# Observation with 4 tranches

# %%
futures_equity = (futures_strat + 1).cumprod()
futures_equity_net = (futures_strat_net + 1).cumprod()
futures_equity_hold = (hold_futures_strat + 1).cumprod()
futures_equity_hold_net = (hold_futures_strat_net + 1).cumprod()


btc = rts['BTC'].reindex(futures_equity.index)
btc = (1 + btc).cumprod()
eth = rts['ETH'].reindex(futures_equity.index)
eth = (1 + eth).cumprod()
bnb = rts['BNB'].reindex(futures_equity.index)
bnb = (1 + bnb).cumprod()

plt.figure(figsize=(10, 5))

plt.plot(futures_equity, label='Futures Startegy')
plt.plot(futures_equity_net, label='Futures Startegy Net')

plt.plot(futures_equity_hold, label='Futures Startegy Hold')
plt.plot(futures_equity_hold_net, label='Futures Startegy Hold Net')

plt.plot(btc, label='Bitcoin')
plt.plot(eth, label='Ethereum')
plt.plot(bnb, label='BNB')

plt.legend()
plt.grid()
plt.show()

# %%
API_KEY = os.environ["BNB_KEY"]
headers = {"X-MBX-APIKEY": API_KEY}
resp = requests.get(
    "https://api.binance.com/sapi/v1/margin/allPairs",
    headers=headers,
    timeout=15,
)
info = resp.json()

# %%
info
# Out:
# [{'id': 351637150141315861,
#   'symbol': 'BNBBTC',
#   'base': 'BNB',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 351637923235429141,
#   'symbol': 'TRXBTC',
#   'base': 'TRX',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 351638112213990165,
#   'symbol': 'XRPBTC',
#   'base': 'XRP',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 351638524530850581,
#   'symbol': 'ETHBTC',
#   'base': 'ETH',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 418310092140600180,
#   'symbol': 'LINKBTC',
#   'base': 'LINK',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 424132564555422744,
#   'symbol': 'ADABTC',
#   'base': 'ADA',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 434000758724123871,
#   'symbol': 'BTCUSDC',
#   'base': 'BTC',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 434038468536982427,
#   'symbol': 'LTCBTC',
#   'base': 'LTC',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 464346609635908836,
#   'symbol': 'ZECBTC',
#   'base': 'ZEC',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 499940841863797809,
#   'symbol': 'XRPETH',
#   'base': 'XRP',
#   'quote': 'ETH',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 501428644304935729,
#   'symbol': 'BNBETH',
#   'base': 'BNB',
#   'quote': 'ETH',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 516874489162652539,
#   'symbol': 'BCHBTC',
#   'base': 'BCH',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 703229134406442267,
#   'symbol': 'ETHUSDC',
#   'base': 'ETH',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 724715713327029393,
#   'symbol': 'DOGEBTC',
#   'base': 'DOGE',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 742585715036019748,
#   'symbol': 'AVAXBTC',
#   'base': 'AVAX',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 871045317821231163,
#   'symbol': 'LTCUSDC',
#   'base': 'LTC',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 871045403720561299,
#   'symbol': 'XRPUSDC',
#   'base': 'XRP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 895510929008015719,
#   'symbol': 'SOLBTC',
#   'base': 'SOL',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 998058521650007922,
#   'symbol': 'PONDBTC',
#   'base': 'POND',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1046276934071225467,
#   'symbol': 'LUNABTC',
#   'base': 'LUNA',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1416070371261552332,
#   'symbol': 'ARBBTC',
#   'base': 'ARB',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1565084742632629097,
#   'symbol': 'WBETHETH',
#   'base': 'WBETH',
#   'quote': 'ETH',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1621480678296150141,
#   'symbol': 'BNBUSDC',
#   'base': 'BNB',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1622742780205878092,
#   'symbol': 'SOLETH',
#   'base': 'SOL',
#   'quote': 'ETH',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1633966027966545141,
#   'symbol': 'SOLUSDC',
#   'base': 'SOL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1650286706122854613,
#   'symbol': 'INJUSDC',
#   'base': 'INJ',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1650287316008208620,
#   'symbol': 'OPUSDC',
#   'base': 'OP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1650287487806871807,
#   'symbol': 'DOTUSDC',
#   'base': 'DOT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1650288673217872150,
#   'symbol': 'ORDIUSDC',
#   'base': 'ORDI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1650288776297092720,
#   'symbol': 'ARBUSDC',
#   'base': 'ARB',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1663694442969727254,
#   'symbol': 'AVAXUSDC',
#   'base': 'AVAX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1664273756748529007,
#   'symbol': 'ADAUSDC',
#   'base': 'ADA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1688945036739222852,
#   'symbol': 'DOGEUSDC',
#   'base': 'DOGE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1688945045329163953,
#   'symbol': 'WLDUSDC',
#   'base': 'WLD',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1688945045329166013,
#   'symbol': 'SUIUSDC',
#   'base': 'SUI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1688945053919105411,
#   'symbol': 'LINKUSDC',
#   'base': 'LINK',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1688945053919114813,
#   'symbol': 'PEPEUSDC',
#   'base': 'PEPE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1688972292601684279,
#   'symbol': 'WBTCBTC',
#   'base': 'WBTC',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1689812654492755719,
#   'symbol': 'SHIBUSDC',
#   'base': 'SHIB',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1700059853755528928,
#   'symbol': 'NEARUSDC',
#   'base': 'NEAR',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1701474246615675459,
#   'symbol': 'ALTUSDC',
#   'base': 'ALT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1701474255205570085,
#   'symbol': 'PENDLEUSDC',
#   'base': 'PENDLE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1701474263795512941,
#   'symbol': 'BCHUSDC',
#   'base': 'BCH',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1705846471783363534,
#   'symbol': 'FILUSDC',
#   'base': 'FIL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1708303356285431139,
#   'symbol': 'NEOUSDC',
#   'base': 'NEO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1709543768610310673,
#   'symbol': 'WIFUSDC',
#   'base': 'WIF',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1711286511720217409,
#   'symbol': 'TIAUSDC',
#   'base': 'TIA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1711286520310141798,
#   'symbol': 'BOMEUSDC',
#   'base': 'BOME',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1714881528195985498,
#   'symbol': 'BONKUSDC',
#   'base': 'BONK',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1714881528195987766,
#   'symbol': 'ENAUSDC',
#   'base': 'ENA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1740920033715971135,
#   'symbol': 'ETHFIUSDC',
#   'base': 'ETHFI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1761743976492192407,
#   'symbol': 'CRVUSDC',
#   'base': 'CRV',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1766704010884047645,
#   'symbol': 'FETUSDC',
#   'base': 'FET',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1766704019473973832,
#   'symbol': 'FLOKIUSDC',
#   'base': 'FLOKI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1766704028063902350,
#   'symbol': 'NOTUSDC',
#   'base': 'NOT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1766704028064000696,
#   'symbol': 'ZROUSDC',
#   'base': 'ZRO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1772629828801921120,
#   'symbol': 'ENSUSDC',
#   'base': 'ENS',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1772629828801961956,
#   'symbol': 'ATOMUSDC',
#   'base': 'ATOM',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1772629837391870171,
#   'symbol': 'CFXUSDC',
#   'base': 'CFX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1772629837391882430,
#   'symbol': 'SAGAUSDC',
#   'base': 'SAGA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1772629845981804899,
#   'symbol': 'ICPUSDC',
#   'base': 'ICP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1772629845981836415,
#   'symbol': 'BBUSDC',
#   'base': 'BB',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1772629854571731890,
#   'symbol': 'SEIUSDC',
#   'base': 'SEI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1772629854571754388,
#   'symbol': 'YGGUSDC',
#   'base': 'YGG',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1777213701368069807,
#   'symbol': 'STRKUSDC',
#   'base': 'STRK',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1777213701368092323,
#   'symbol': 'TRBUSDC',
#   'base': 'TRB',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1777213709957992565,
#   'symbol': 'RUNEUSDC',
#   'base': 'RUNE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1777213709958008885,
#   'symbol': 'ZKUSDC',
#   'base': 'ZK',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1777213718547924150,
#   'symbol': 'UNIUSDC',
#   'base': 'UNI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1777213718547931553,
#   'symbol': 'GALAUSDC',
#   'base': 'GALA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1777213727137858626,
#   'symbol': 'ARUSDC',
#   'base': 'AR',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1777213727137898831,
#   'symbol': '1000SATSUSDC',
#   'base': '1000SATS',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1777213727137949747,
#   'symbol': 'PEOPLEUSDC',
#   'base': 'PEOPLE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1780281313039784703,
#   'symbol': 'RENDERUSDC',
#   'base': 'RENDER',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1782290378481745995,
#   'symbol': 'LDOUSDC',
#   'base': 'LDO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1782290387071666524,
#   'symbol': 'PIXELUSDC',
#   'base': 'PIXEL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1782290387071671326,
#   'symbol': 'MANTAUSDC',
#   'base': 'MANTA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1782290395661636581,
#   'symbol': 'STXUSDC',
#   'base': 'STX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1782290404251535708,
#   'symbol': 'JTOUSDC',
#   'base': 'JTO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1782290404251554499,
#   'symbol': 'IOUSDC',
#   'base': 'IO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1793596811169016831,
#   'symbol': 'ONTUSDC',
#   'base': 'ONT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1794180084907654350,
#   'symbol': 'BLURUSDC',
#   'base': 'BLUR',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1794180093497592925,
#   'symbol': 'REZUSDC',
#   'base': 'REZ',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1794180102087550917,
#   'symbol': 'APTUSDC',
#   'base': 'APT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1794180102087551324,
#   'symbol': 'ALGOUSDC',
#   'base': 'ALGO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1794180110677442630,
#   'symbol': 'TNSRUSDC',
#   'base': 'TNSR',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1797885593712114640,
#   'symbol': 'JUPUSDC',
#   'base': 'JUP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1804785269694540213,
#   'symbol': 'TONUSDC',
#   'base': 'TON',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1804880008083171572,
#   'symbol': 'DOGSUSDC',
#   'base': 'DOGS',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1804880076802637569,
#   'symbol': 'RAREUSDC',
#   'base': 'RARE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1809971245135975958,
#   'symbol': 'AAVEUSDC',
#   'base': 'AAVE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1809971253725889741,
#   'symbol': 'TRXUSDC',
#   'base': 'TRX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1841882061871281881,
#   'symbol': 'BNSOLSOL',
#   'base': 'BNSOL',
#   'quote': 'SOL',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1863369405296021156,
#   'symbol': 'NEIROUSDC',
#   'base': 'NEIRO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1863369413885984917,
#   'symbol': 'ACTUSDC',
#   'base': 'ACT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1868568703726007595,
#   'symbol': 'CATIUSDC',
#   'base': 'CATI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1868568712315933052,
#   'symbol': 'TAOUSDC',
#   'base': 'TAO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1868568712315976344,
#   'symbol': 'RAYUSDC',
#   'base': 'RAY',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1868568720905863946,
#   'symbol': 'HBARUSDC',
#   'base': 'HBAR',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1873038098233828399,
#   'symbol': 'MEMEUSDC',
#   'base': 'MEME',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1873038098233853779,
#   'symbol': 'EIGENUSDC',
#   'base': 'EIGEN',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1873038106823771874,
#   'symbol': 'APEUSDC',
#   'base': 'APE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1873771549798969583,
#   'symbol': 'TURBOUSDC',
#   'base': 'TURBO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1873771549798996835,
#   'symbol': 'HMSTRUSDC',
#   'base': 'HMSTR',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1873771558388899526,
#   'symbol': 'DYDXUSDC',
#   'base': 'DYDX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1873771566978826654,
#   'symbol': 'CETUSUSDC',
#   'base': 'CETUS',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1873771566978864919,
#   'symbol': 'COWUSDC',
#   'base': 'COW',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1873771575568803135,
#   'symbol': '1MBABYDOGEUSDC',
#   'base': '1MBABYDOGE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1876031467100865139,
#   'symbol': 'SUIBTC',
#   'base': 'SUI',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1877603854627912902,
#   'symbol': 'XLMUSDC',
#   'base': 'XLM',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1877603854627937123,
#   'symbol': 'SANDUSDC',
#   'base': 'SAND',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1877603863217844497,
#   'symbol': 'KAIAUSDC',
#   'base': 'KAIA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1878984832642495402,
#   'symbol': 'XTZUSDC',
#   'base': 'XTZ',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1878984901361954501,
#   'symbol': 'WUSDC',
#   'base': 'W',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1878984901361975280,
#   'symbol': 'RSRUSDC',
#   'base': 'RSR',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1878984909951875959,
#   'symbol': 'PYTHUSDC',
#   'base': 'PYTH',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1878984909951907551,
#   'symbol': 'CHZUSDC',
#   'base': 'CHZ',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1882676820889837923,
#   'symbol': 'ORCAUSDC',
#   'base': 'ORCA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1882676829479764640,
#   'symbol': 'ACXUSDC',
#   'base': 'ACX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1884189070284816551,
#   'symbol': 'TLMUSDC',
#   'base': 'TLM',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1884189078874756620,
#   'symbol': 'HIVEUSDC',
#   'base': 'HIVE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1888619088532485691,
#   'symbol': 'PENGUUSDC',
#   'base': 'PENGU',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1888619097122451190,
#   'symbol': '1000CATUSDC',
#   'base': '1000CAT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1903474744754182643,
#   'symbol': 'MOVEUSDC',
#   'base': 'MOVE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1903474753344151095,
#   'symbol': 'BIOUSDC',
#   'base': 'BIO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1904986040666469838,
#   'symbol': 'USUALUSDC',
#   'base': 'USUAL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1904986049256373918,
#   'symbol': 'PHAUSDC',
#   'base': 'PHA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1904986049256378337,
#   'symbol': 'STEEMUSDC',
#   'base': 'STEEM',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1905135935025065278,
#   'symbol': 'COOKIEUSDC',
#   'base': 'COOKIE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1905135943614990191,
#   'symbol': 'CGPTUSDC',
#   'base': 'CGPT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1905135943615015440,
#   'symbol': 'AIXBTUSDC',
#   'base': 'AIXBT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1909448966953504995,
#   'symbol': 'SUSDC',
#   'base': 'S',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1911691274889466009,
#   'symbol': 'TRUMPUSDC',
#   'base': 'TRUMP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1914861347301000557,
#   'symbol': 'ANIMEUSDC',
#   'base': 'ANIME',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1925189996323546882,
#   'symbol': 'BERAUSDC',
#   'base': 'BERA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1927353938286226578,
#   'symbol': '1000CHEEMSUSDC',
#   'base': '1000CHEEMS',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1927353946876198282,
#   'symbol': 'TSTUSDC',
#   'base': 'TST',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1928931393874713782,
#   'symbol': 'LAYERUSDC',
#   'base': 'LAYER',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1933955440459150072,
#   'symbol': 'CAKEUSDC',
#   'base': 'CAKE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1935534004149205469,
#   'symbol': 'KAITOUSDC',
#   'base': 'KAITO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1940697662940539398,
#   'symbol': 'SHELLUSDC',
#   'base': 'SHELL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1944403721500780136,
#   'symbol': 'GPSUSDC',
#   'base': 'GPS',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1945981151319456936,
#   'symbol': 'REDUSDC',
#   'base': 'RED',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1949610183936219967,
#   'symbol': 'TUSDC',
#   'base': 'T',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1949610192526129205,
#   'symbol': 'OSMOUSDC',
#   'base': 'OSMO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1949610192526142086,
#   'symbol': 'EGLDUSDC',
#   'base': 'EGLD',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1953953048707470064,
#   'symbol': 'VELODROMEUSDC',
#   'base': 'VELODROME',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1953953048707484686,
#   'symbol': 'SYNUSDC',
#   'base': 'SYN',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1953953048707491902,
#   'symbol': 'EURIUSDC',
#   'base': 'EURI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1953953057297428395,
#   'symbol': 'CVCUSDC',
#   'base': 'CVC',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1954856203020441473,
#   'symbol': 'BMTUSDC',
#   'base': 'BMT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1959143490914917295,
#   'symbol': 'VANRYUSDC',
#   'base': 'VANRY',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1959143499504839399,
#   'symbol': 'THEUSDC',
#   'base': 'THE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1959143508094756031,
#   'symbol': 'IOTAUSDC',
#   'base': 'IOTA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1959143508094792766,
#   'symbol': 'RPLUSDC',
#   'base': 'RPL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1959143516684725310,
#   'symbol': 'EPICUSDC',
#   'base': 'EPIC',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1959247283094586292,
#   'symbol': 'NILUSDC',
#   'base': 'NIL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1959759595383584103,
#   'symbol': 'FORMUSDC',
#   'base': 'FORM',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1959989693961516893,
#   'symbol': 'PARTIUSDC',
#   'base': 'PARTI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1964437759661716818,
#   'symbol': 'MUBARAKUSDC',
#   'base': 'MUBARAK',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1964438438266539799,
#   'symbol': 'BANANAS31USDC',
#   'base': 'BANANAS31',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1964438438266578556,
#   'symbol': 'TUTUSDC',
#   'base': 'TUT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1966481133302449713,
#   'symbol': 'VANAUSDC',
#   'base': 'VANA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1966481141892425358,
#   'symbol': 'BEAMXUSDC',
#   'base': 'BEAMX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1969493606184010452,
#   'symbol': 'THETAUSDC',
#   'base': 'THETA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1969493606184038192,
#   'symbol': 'QNTUSDC',
#   'base': 'QNT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1969493614773936386,
#   'symbol': 'BANANAUSDC',
#   'base': 'BANANA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1969493614773958655,
#   'symbol': 'GUNUSDC',
#   'base': 'GUN',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1969493614773960572,
#   'symbol': 'AUCTIONUSDC',
#   'base': 'AUCTION',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1971801859047854338,
#   'symbol': 'BABYUSDC',
#   'base': 'BABY',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1972637118517764395,
#   'symbol': 'VIRTUALUSDC',
#   'base': 'VIRTUAL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1972637127107692437,
#   'symbol': 'ONDOUSDC',
#   'base': 'ONDO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1974801636006052604,
#   'symbol': 'KERNELUSDC',
#   'base': 'KERNEL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1975512779511078083,
#   'symbol': 'WCTUSDC',
#   'base': 'WCT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1980770317697585485,
#   'symbol': 'HYPERUSDC',
#   'base': 'HYPER',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1982192329829678676,
#   'symbol': 'INITUSDC',
#   'base': 'INIT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1985161552390566245,
#   'symbol': 'SIGNUSDC',
#   'base': 'SIGN',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1985977338478735546,
#   'symbol': 'VETUSDC',
#   'base': 'VET',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1985977347068705026,
#   'symbol': 'API3USDC',
#   'base': 'API3',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1985977355658684737,
#   'symbol': 'ACHUSDC',
#   'base': 'ACH',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1985977364248555427,
#   'symbol': 'GMTUSDC',
#   'base': 'GMT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1985977364248564989,
#   'symbol': 'ZENUSDC',
#   'base': 'ZEN',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1988284354391971545,
#   'symbol': 'STOUSDC',
#   'base': 'STO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1991222532929268320,
#   'symbol': 'KMNOUSDC',
#   'base': 'KMNO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1991222627418536499,
#   'symbol': 'SYRUPUSDC',
#   'base': 'SYRUP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1992645017507725439,
#   'symbol': 'SXTUSDC',
#   'base': 'SXT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1995472772435812046,
#   'symbol': 'ENJUSDC',
#   'base': 'ENJ',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 1997670472841463287,
#   'symbol': 'NXPCUSDC',
#   'base': 'NXPC',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2002370034646663164,
#   'symbol': 'HAEDALUSDC',
#   'base': 'HAEDAL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2006002451697649619,
#   'symbol': 'HUMAUSDC',
#   'base': 'HUMA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2007325825610819550,
#   'symbol': 'AUSDC',
#   'base': 'A',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2007522045486729841,
#   'symbol': 'SOPHUSDC',
#   'base': 'SOPH',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2017901469612685425,
#   'symbol': 'RESOLVUSDC',
#   'base': 'RESOLV',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2018643949199074772,
#   'symbol': 'HOMEUSDC',
#   'base': 'HOME',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2022184771777488614,
#   'symbol': 'SPKUSDC',
#   'base': 'SPK',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2026529062477918698,
#   'symbol': 'SUSHIUSDC',
#   'base': 'SUSHI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2026529071067836384,
#   'symbol': 'FLUXUSDC',
#   'base': 'FLUX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2026529071067869254,
#   'symbol': 'MASKUSDC',
#   'base': 'MASK',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2027533380450530311,
#   'symbol': 'NEWTUSDC',
#   'base': 'NEWT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2028962470688740469,
#   'symbol': 'SAHARAUSDC',
#   'base': 'SAHARA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2034813848233468326,
#   'symbol': 'RVNUSDC',
#   'base': 'RVN',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2034813874003260423,
#   'symbol': 'LPTUSDC',
#   'base': 'LPT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2038722491811113368,
#   'symbol': 'LAUSDC',
#   'base': 'LA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2044653626898525596,
#   'symbol': 'ERAUSDC',
#   'base': 'ERA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2045266115004728126,
#   'symbol': 'XAIUSDC',
#   'base': 'XAI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2045266140774544539,
#   'symbol': 'COMPUSDC',
#   'base': 'COMP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2045266175134286006,
#   'symbol': 'AXSUSDC',
#   'base': 'AXS',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2045347985671325027,
#   'symbol': 'CUSDC',
#   'base': 'C',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2050514556450509214,
#   'symbol': 'ROSEUSDC',
#   'base': 'ROSE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2050514607990112522,
#   'symbol': 'GRTUSDC',
#   'base': 'GRT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2050514633760014802,
#   'symbol': 'ETCUSDC',
#   'base': 'ETC',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2053508612512321034,
#   'symbol': 'TREEUSDC',
#   'base': 'TREE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2055528183444298064,
#   'symbol': 'CVXUSDC',
#   'base': 'CVX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2055528192034225825,
#   'symbol': 'LISTAUSDC',
#   'base': 'LISTA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2058706433473540972,
#   'symbol': 'TOWNSUSDC',
#   'base': 'TOWNS',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2058777197354698030,
#   'symbol': 'PROVEUSDC',
#   'base': 'PROVE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2066021750621123991,
#   'symbol': 'MAGICUSDC',
#   'base': 'MAGIC',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2066021759211015841,
#   'symbol': 'ILVUSDC',
#   'base': 'ILV',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2068385683440948180,
#   'symbol': 'PLUMEUSDC',
#   'base': 'PLUME',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2071302464451139249,
#   'symbol': 'SKLUSDC',
#   'base': 'SKL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2071302473041073043,
#   'symbol': 'CYBERUSDC',
#   'base': 'CYBER',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2075086768725562068,
#   'symbol': 'DOLOUSDC',
#   'base': 'DOLO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2076564297604931459,
#   'symbol': 'MITOUSDC',
#   'base': 'MITO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2078703809793646819,
#   'symbol': 'UMAUSDC',
#   'base': 'UMA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2078703809793654818,
#   'symbol': 'SSVUSDC',
#   'base': 'SSV',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2078705656629586878,
#   'symbol': 'WLFIUSDC',
#   'base': 'WLFI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2079492193990500579,
#   'symbol': 'SOMIUSDC',
#   'base': 'SOMI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2085470968855134520,
#   'symbol': 'LINEAUSDC',
#   'base': 'LINEA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2088777062880933491,
#   'symbol': 'PUMPUSDC',
#   'base': 'PUMP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2088941534358581245,
#   'symbol': 'AVNTUSDC',
#   'base': 'AVNT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2089124362526427103,
#   'symbol': 'ZKCUSDC',
#   'base': 'ZKC',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2090432781363491087,
#   'symbol': 'SKYUSDC',
#   'base': 'SKY',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2091256023514911743,
#   'symbol': 'BARDUSDC',
#   'base': 'BARD',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2094195799779980040,
#   'symbol': '0GUSDC',
#   'base': '0G',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2094984046537879431,
#   'symbol': 'HEMIUSDC',
#   'base': 'HEMI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2096510374835665396,
#   'symbol': 'XPLUSDC',
#   'base': 'XPL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2097229094663008373,
#   'symbol': 'MIRAUSDC',
#   'base': 'MIRA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2097341055870438140,
#   'symbol': 'TWTUSDC',
#   'base': 'TWT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2097341055870451922,
#   'symbol': 'IMXUSDC',
#   'base': 'IMX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2099481143584781491,
#   'symbol': 'FFUSDC',
#   'base': 'FF',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2100165727012039191,
#   'symbol': 'EDENUSDC',
#   'base': 'EDEN',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2100818716659825294,
#   'symbol': 'NOMUSDC',
#   'base': 'NOM',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2101719397071606750,
#   'symbol': '2ZUSDC',
#   'base': '2Z',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2102514936683990246,
#   'symbol': 'MORPHOUSDC',
#   'base': 'MORPHO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2102543386547367370,
#   'symbol': 'SNXUSDC',
#   'base': 'SNX',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2102543395137284488,
#   'symbol': 'MEUSDC',
#   'base': 'ME',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2102543395137293124,
#   'symbol': 'AEVOUSDC',
#   'base': 'AEVO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2104643539655744799,
#   'symbol': 'ASTERUSDC',
#   'base': 'ASTER',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2104719972893758287,
#   'symbol': 'SOLBNB',
#   'base': 'SOL',
#   'quote': 'BNB',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2107465530737721567,
#   'symbol': 'WALUSDC',
#   'base': 'WAL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2109906386421844854,
#   'symbol': 'EULUSDC',
#   'base': 'EUL',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2110496489158495889,
#   'symbol': 'ENSOUSDC',
#   'base': 'ENSO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2111293102512681330,
#   'symbol': 'YBUSDC',
#   'base': 'YB',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2112849839178940118,
#   'symbol': 'ZBTUSDC',
#   'base': 'ZBT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2116610005737191172,
#   'symbol': 'TURTLEUSDC',
#   'base': 'TURTLE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2118562618129020682,
#   'symbol': 'GIGGLEUSDC',
#   'base': 'GIGGLE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2125455748581327573,
#   'symbol': 'KITEUSDC',
#   'base': 'KITE',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2126178832095404950,
#   'symbol': 'MMTUSDC',
#   'base': 'MMT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2131399545232310835,
#   'symbol': 'ALLOUSDC',
#   'base': 'ALLO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2132909363675807852,
#   'symbol': 'BANKUSDC',
#   'base': 'BANK',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2132909363675840130,
#   'symbol': 'METUSDC',
#   'base': 'MET',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2133435961026031015,
#   'symbol': 'SOLVUSDC',
#   'base': 'SOLV',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2133435969615990587,
#   'symbol': 'MINAUSDC',
#   'base': 'MINA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2133435978205914165,
#   'symbol': 'ZECUSDC',
#   'base': 'ZEC',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2133435986795848261,
#   'symbol': 'DASHUSDC',
#   'base': 'DASH',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2138655548881521521,
#   'symbol': 'COTIUSDC',
#   'base': 'COTI',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2138655557471480769,
#   'symbol': '1INCHUSDC',
#   'base': '1INCH',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2143298133650581807,
#   'symbol': 'ATUSDC',
#   'base': 'AT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2166935915660846718,
#   'symbol': 'LUNCUSDC',
#   'base': 'LUNC',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2166935915660882630,
#   'symbol': 'LUNAUSDC',
#   'base': 'LUNA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2172985901083266957,
#   'symbol': 'BREVUSDC',
#   'base': 'BREV',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2173728380669700607,
#   'symbol': 'ZKPUSDC',
#   'base': 'ZKP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2174316731059693072,
#   'symbol': '币安人生USDC',
#   'base': '币安人生',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2179669334052337286,
#   'symbol': 'FOGOUSDC',
#   'base': 'FOGO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2184797396154733515,
#   'symbol': 'SENTUSDC',
#   'base': 'SENT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2193000508812166207,
#   'symbol': 'ZAMAUSDC',
#   'base': 'ZAMA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2200416963849620444,
#   'symbol': 'ESPUSDC',
#   'base': 'ESP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2215108191543403011,
#   'symbol': 'MANTRAUSDC',
#   'base': 'MANTRA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2215368715669621410,
#   'symbol': 'ROBOUSDC',
#   'base': 'ROBO',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2216003108109067762,
#   'symbol': 'OPNUSDC',
#   'base': 'OPN',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2220545379621959943,
#   'symbol': 'NIGHTUSDC',
#   'base': 'NIGHT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2224169000579895691,
#   'symbol': 'CFGUSDC',
#   'base': 'CFG',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2225652327665141518,
#   'symbol': 'KATUSDC',
#   'base': 'KAT',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2250914019630150882,
#   'symbol': 'CHIPUSDC',
#   'base': 'CHIP',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2257505849536706570,
#   'symbol': 'MEGAUSDC',
#   'base': 'MEGA',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2268005300818742999,
#   'symbol': 'AIGENSYNUSDC',
#   'base': 'AIGENSYN',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2273789376225894795,
#   'symbol': 'GENIUSUSDC',
#   'base': 'GENIUS',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'id': 2273792425652667063,
#   'symbol': 'OPGUSDC',
#   'base': 'OPG',
#   'quote': 'USDC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True}]

# %%
margin_pairs = {}
for s in info:
    margin_pairs[s['base']] = s['symbol']

# %%
excluded = set(STABLECOINS_HARDCODED) | WRAPPED_TOKENS | stablecoins
margin_candidates = []
for c in coins:
    sym = c["symbol"].upper()
    if sym in excluded:
        continue
    if sym in margin_pairs:
        margin_candidates.append({
            "symbol": sym,
            "binance_margin": margin_pairs[sym],
            "coin_id": c["id"],
            "name": c["name"],
            "rank": c.get("market_cap_rank", 999),
        })
    if len(margin_candidates) >= 100:
        break

# %%
margin_filter = [c['binance_margin'] for c in margin_candidates]
margin = []

for symbol in margin_filter:
    resp = binance.get_klines(symbol, source='SPOT', days=365)
    margin.extend(resp)

df_margin = pd.DataFrame(margin)
df_margin['date'] = pd.to_datetime(df_margin["date"])
df_margin
# Out:
#         symbol        date         open         high          low  \
# 0      BTCUSDC  2025-05-27  109478.0100  110799.1000  107547.1300
# 1      BTCUSDC  2025-05-28  108992.9200  109334.9200  106814.8500
# 2      BTCUSDC  2025-05-29  107817.9800  108941.1700  105333.0000
# 3      BTCUSDC  2025-05-30  105586.0300  106342.0000  103657.4000
# 4      BTCUSDC  2025-05-31  104041.7600  104958.3200  103127.0000
# ...        ...         ...          ...          ...          ...
# 33251    AUSDC  2026-05-22       0.0817       0.0825       0.0769
# 33252    AUSDC  2026-05-23       0.0776       0.0819       0.0757
# 33253    AUSDC  2026-05-24       0.0806       0.0812       0.0767
# 33254    AUSDC  2026-05-25       0.0780       0.0806       0.0777
# 33255    AUSDC  2026-05-26       0.0792       0.0803       0.0778
#
#              close   volume_base   volume_usdt   trades
# 0      108992.9200    4879.95661  5.345024e+08   938591
# 1      107817.9800    3549.21863  3.838646e+08   825601
# 2      105586.0300    4356.44792  4.672355e+08  1109751
# 3      104041.7700    5076.54853  5.333837e+08  1301466
# 4      104647.9900    2453.56534  2.552657e+08   455074
# ...            ...           ...           ...      ...
# 33251       0.0776  914050.70000  7.334255e+04     1600
# 33252       0.0803  372785.60000  2.944404e+04      522
# 33253       0.0778  523616.50000  4.191504e+04     1186
# 33254       0.0795   40301.00000  3.198210e+03       62
# 33255       0.0803   69112.30000  5.452716e+03       73
#
# [33256 rows x 9 columns]

# %%
df_margin = df_margin[df_margin["symbol"] != "ETCUSDC"]
df_margin = df_margin[df_margin["symbol"] != "ZECUSDC"]

# %%
margin_volume = pd.pivot_table(df_margin, values='volume_usdt', index='date', columns='symbol')
margin_px = pd.pivot_table(df_margin, values='close', index='date', columns='symbol')
margin_rts = margin_px.pct_change().shift(-1)

# %%
short_sma= margin_volume.rolling(SHORT_SMA).mean()
long_sma = margin_volume.rolling(LONG_SMA).mean()
rvol = short_sma / long_sma

signal_margin = {}

for i, row in rvol.iterrows():

    clean = row.dropna()
    
    if clean.notna().sum() >= 10:
        top = clean.nlargest(5)
        bot = clean.nsmallest(5)

        signal_margin[i] = {
            'top': list(top.index),
            'bot': list(bot.index)
        }

# %%
fee_rate = 0.001
margin_strat = {}
margin_strat_net = {}

prev_weights = pd.Series(0, index=margin_rts.columns)

for i, row in margin_rts.iterrows():
    selection = signal_margin.get(i, None)
    
    if selection is not None:
        
        top_symbols = selection['top']
        bot_symbols = selection['bot']
        long = row[top_symbols].mean()
        short = -row[bot_symbols].mean()

        weights = pd.Series(0.0, index=row.index)
        weights_long = weights.copy()

        weights[top_symbols] =  1 / len(top_symbols)
        weights[bot_symbols] = -1 / len(bot_symbols)
        
        gross_return = (weights * row).sum()
        turnover = (weights - prev_weights).abs().sum()
        transaction_cost = turnover * fee_rate
        net_return = gross_return - transaction_cost
        
        portfolio = long + short
        
        margin_strat[i] = portfolio
        margin_strat_net[i] = net_return

        prev_weights = weights
        
margin_strat = pd.Series(margin_strat)
margin_strat_net = pd.Series(margin_strat_net)

# %%
margin_strat
# Out:
# 2025-06-25   -0.011380
# 2025-06-26    0.030684
# 2025-06-27   -0.047531
# 2025-06-28   -0.041510
# 2025-06-29   -0.013457
#                 ...
# 2026-05-22    0.040980
# 2026-05-23    0.011375
# 2026-05-24    0.048245
# 2026-05-25    0.073109
# 2026-05-26         NaN
# Length: 336, dtype: float64

# %%
margin_equity = (margin_strat + 1).cumprod()
margin_equity_net = (margin_strat_net + 1).cumprod()
# futures_equity_hold = (hold_futures_strat + 1).cumprod()
# futures_equity_hold_net = (hold_futures_strat_net + 1).cumprod()


btc = rts['BTC'].reindex(futures_equity.index)
btc = (1 + btc).cumprod()
eth = rts['ETH'].reindex(futures_equity.index)
eth = (1 + eth).cumprod()
bnb = rts['BNB'].reindex(futures_equity.index)
bnb = (1 + bnb).cumprod()

plt.figure(figsize=(10, 5))

plt.plot(margin_equity, label='Margin Startegy')
plt.plot(margin_equity_net, label='Margin Startegy Net')

# plt.plot(futures_equity_hold, label='Futures Startegy Hold')
# plt.plot(futures_equity_hold_net, label='Futures Startegy Hold Net')

plt.plot(btc, label='Bitcoin')
plt.plot(eth, label='Ethereum')
plt.plot(bnb, label='BNB')

plt.legend()
plt.grid()
plt.show()
